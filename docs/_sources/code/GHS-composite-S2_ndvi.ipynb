# %% [markdown]
# # NDVI
#
# This document shows the computation of NDVI scores for each of the enclosed tesselations (ETs) in GB.

# %%
! echo "Run this notebook using version $GDS_ENV_VERSION of the gds_env"
SERVER_IP = open("../../SERVER_IP").read().strip("\n")
# Out:
# Run this notebook using version 6.0alpha of the gds_env

# %% [markdown]
# ## Set up

# %% [markdown]
# Since we will run some computations on a Dask cluster, let's set it up first:

# %%
! cat ../../worker-spec.yml
# Out:
# kind: Pod
# metadata:
#   labels:
#     foo: bar
# spec:
#   restartPolicy: Never
#   containers:
#   - image: darribas/gds_py:6.0alpha1
#     imagePullPolicy: IfNotPresent
#     args: [start.sh, dask-worker, --nthreads, '2', --no-dashboard, --memory-limit, 2GB, --death-timeout, '60']
#     name: dask
#     resources:
#       limits:
#         cpu: "1"
#         memory: 2G
#       requests:
#         cpu: "1"
#         memory: 2G

# %%
from dask_kubernetes import KubeCluster
from dask.distributed import Client
import dask.array as da

# Set up cluster
cluster = KubeCluster.from_yaml('../../worker-spec.yml')
# Provision with up to 30 pods
cluster.scale(50)
# Connect Dask to the cluster
client = Client(cluster)
# Out:
# distributed.scheduler - INFO - Clear task state
# distributed.scheduler - INFO -   Scheduler at: tcp://138.253.73.24:37297
# distributed.scheduler - INFO -   dashboard at:                     :8787
# distributed.scheduler - INFO - Receive client connection: Client-106cf4b4-3296-11eb-8594-80e82cd20b5e
# distributed.core - INFO - Starting established connection

# %%
cluster
# Out:
# distributed.scheduler - INFO - Register worker <Worker 'tcp://10.1.151.210:36721', name: 36, memory: 0, processing: 0>
# distributed.scheduler - INFO - Starting worker compute stream, tcp://10.1.151.210:36721
# VBox(children=(HTML(value='<h2>KubeCluster</h2>'), HBox(children=(HTML(value='\n<div>\n  <style scoped>\n    .…
# distributed.core - INFO - Starting established connection

# %% [markdown]
# Bring on other libs we'll use:

# %%
import os
import fsspec
import pandas
import geopandas
import rioxarray, xarray
from dask import dataframe as dd
from numpy import percentile

# %% [markdown]
# ## Connecting to the GHS Mosaic

# %% [markdown]
# The full mosaic is stored as a folder of COGs served over HTTP. First let's grab the URL for the mosaic:

# %%
mosaic_url = f"http://{SERVER_IP}:8000/ghs_composite_s2/GHS-composite-S2.vrt"

# %% [markdown]
# We inspect the details of the mosaic to select the chunk:

# %%
! rio info $mosaic_url | python -m json.tool
# Out:
# {
#     "blockxsize": 128,
#     "blockysize": 128,
#     "bounds": [
#         -222823.73719089525,
#         -213574.25107683009,
#         996789.2497132053,
#         1612237.380579703
#     ],
#     "colorinterp": [
#         "gray",
#         "undefined",
#         "undefined",
#         "undefined"
#     ],
#     "count": 4,
#     "crs": "EPSG:27700",
#     "descriptions": [
#         null,
#         null,
#         null,
#         null
#     ],
#     "driver": "VRT",
#     "dtype": "uint16",
#     "height": 182437,
#     "indexes": [
#         1,
#         2,
#         3,
#         4
#     ],
#     "lnglat": [
#         -2.211309842042783,
#         56.18643258743896
#     ],
#     "mask_flags": [
#         [
#             "nodata"
#         ],
#         [
#             "nodata"
#         ],
#         [
#             "nodata"
#         ],
#         [
#             "nodata"
#         ]
#     ],
#     "nodata": 0.0,
#     "res": [
#         10.007902079383749,
#         10.007902079383749
#     ],
#     "shape": [
#         182437,
#         121865
#     ],
#     "tiled": true,
#     "transform": [
#         10.007902079383749,
#         0.0,
#         -222823.73719089525,
#         0.0,
#         -10.007902079383749,
#         1612237.380579703,
#         0.0,
#         0.0,
#         1.0
#     ],
#     "units": [
#         null,
#         null,
#         null,
#         null
#     ],
#     "width": 121865
# }

# %% [markdown]
# Since it's tiled on 128 by 128 pixels, we pick a chunk size that is ten times larger:

# %%
r = rioxarray.open_rasterio(mosaic_url,
                            chunks={"x": 1280, "y": 1280}
                           )
r
# Out:
# <xarray.DataArray (band: 4, y: 182437, x: 121865)>
# dask.array<open_rasterio-795c3b956cc1d5c020e1f7e90e23a4a6<this-array>, shape=(4, 182437, 121865), dtype=uint16, chunksize=(4, 1280, 1280), chunktype=numpy.ndarray>
# Coordinates:
#   * band         (band) int64 1 2 3 4
#   * y            (y) float64 1.612e+06 1.612e+06 ... -2.136e+05 -2.136e+05
#   * x            (x) float64 -2.228e+05 -2.228e+05 ... 9.968e+05 9.968e+05
#     spatial_ref  int64 0
# Attributes:
#     _FillValue:    0.0
#     scale_factor:  1.0
#     add_offset:    0.0
#     grid_mapping:  spatial_ref

# %% [markdown]
# This will make each chunk in `r` read ten tiles at a time.

# %% [markdown]
# ## Enclosed Tesselation (ET) cells

# %% [markdown]
# The ET cells are stored as parquet files by geographic chunks. Let's read a random one (`#6`) for this illustration:

# %%
tst = geopandas.read_parquet("../../urbangrammar_samba/spatial_signatures/tessellation/tess_6.pq")
tst.head()
# Out:
#              hindex                                       tessellation  \
# 0  c006e658591t0000  POLYGON Z ((356038.093 215849.818 0.000, 35603...
# 1  c006e658591t0105  MULTIPOLYGON Z (((355777.262 216080.707 0.000,...
# 2  c006e658591t0106  POLYGON Z ((355789.951 215942.223 0.000, 35577...
# 3  c006e658591t0107  POLYGON Z ((355804.850 215994.579 0.000, 35578...
# 4  c006e658591t0108  POLYGON Z ((355791.991 216043.449 0.000, 35578...
#
#                                            buildings
# 0  POLYGON ((356035.210 215860.810, 356035.630 21...
# 1  POLYGON ((355762.480 216099.480, 355770.340 21...
# 2  POLYGON ((355774.500 216010.050, 355778.130 21...
# 3  POLYGON ((355785.950 216029.660, 355778.150 21...
# 4  POLYGON ((355787.380 216069.090, 355790.600 21...

# %%
tst_sub = tst.cx[315891.95:330000, 213727.69:250000]
tst_sub.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 2049 entries, 15006 to 258237
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   hindex        2049 non-null   object
#  1   tessellation  2049 non-null   geometry
#  2   buildings     2013 non-null   geometry
# dtypes: geometry(2), object(1)
# memory usage: 64.0+ KB

# %% [markdown]
# ## NDVI computation

# %% [markdown]
# We can express the calculation of the NDVI index, although no computation will take place thanks to `xarray`/Dask's lazy evaluation:

# %%
ndvi = (r.sel(band=4) - r.sel(band=1)) / (r.sel(band=4) + r.sel(band=1))

# %% [markdown]
# ## Distribute computation by ET cell

# %% [markdown]
# With the NDVI expressed, we create a method that allows us to, efficiently, go from a row in our `GeoDataFrame` to the average NDVI for that area:

# %%
def geom2ndvi(row, ndvi, geom="geometry"):
    val = ndvi.rio.clip([row[geom]])\
              .mean()\
              .values\
              .tolist()
    return val

# %% [markdown]
# For example, let's read in a section of the mosaic:

# %%
# %time ndvi_sub = ndvi.rio.clip_box(*tst.total_bounds).load()
ndvi_sub
# Out:
# CPU times: user 3.08 s, sys: 1.3 s, total: 4.38 s
# Wall time: 21.3 s
# <xarray.DataArray (y: 13255, x: 6843)>
# array([[0.61009818, 0.58191489, 0.6251046 , ..., 0.35693936, 0.41908326,
#         0.37449664],
#        [0.6118451 , 0.59004392, 0.60340197, ..., 0.32614108, 0.4478294 ,
#         0.539119  ],
#        [0.60775265, 0.60667569, 0.60054348, ..., 0.2345679 , 0.4243005 ,
#         0.56378601],
#        ...,
#        [0.46993865, 0.46457178, 0.42022008, ..., 0.51605608, 0.518008  ,
#         0.59114016],
#        [0.49168646, 0.48785484, 0.426     , ..., 0.56725979, 0.54575283,
#         0.54658841],
#        [0.52694778, 0.51639578, 0.41390852, ..., 0.54981818, 0.54678051,
#         0.56144751]])
# Coordinates:
#   * y            (y) float64 3.464e+05 3.464e+05 ... 2.137e+05 2.137e+05
#   * x            (x) float64 3.159e+05 3.159e+05 ... 3.844e+05 3.844e+05
#     spatial_ref  int64 0
# Attributes:
#     grid_mapping:  spatial_ref

# %% [markdown]
# And calculate NDVI for a cell within that section:

# %%
# %time geom2ndvi(tst_sub.iloc[0, :], ndvi_sub, geom="tessellation")
# Out:
# CPU times: user 511 ms, sys: 83.6 ms, total: 594 ms
# Wall time: 571 ms
# 0.5895589197001319

# %% [markdown]
# This method can be applied sequentially to an entire table from the URL of the mosaic:
#
# **NOTE** For this to work effectively, the extent of `db.total_bounds` needs to fit comfortably in memory

# %%
def ndvi_from_chunk(db_path,
                    mosaic_path=mosaic_url, 
                    geom="tessellation"
                   ):
    if type(db_path) is pandas.Series:
        db_path = db_path.iloc[0]
    with fsspec.open(db_path) as file:
        db = geopandas.read_parquet(file, 
                                    columns=["hindex", "tessellation"]
                                   ).set_index("hindex").head() # <-- head only!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
    r = rioxarray.open_rasterio(mosaic_path,
                                chunks={
                                    "x": 640, 
                                    "y": 640
                                }
                               )
    ndvi = (r.sel(band=4) - r.sel(band=1)) / \
           (r.sel(band=4) + r.sel(band=1))
    ndvi_vals = ndvi.rio.clip_box(*db.total_bounds).load()
    rower = lambda row: geom2ndvi(row, ndvi_vals, geom=geom)
    return db.apply(rower, axis=1)

# %% [markdown]
# For example:

# %%
# %time ndvis = ndvi_from_chunk(tst_url, mosaic_url, geom="tessellation")
# Out:
# distributed.utils_perf - INFO - full garbage collection released 782.16 MB from 96619 reference cycles (threshold: 10.00 MB)
# CPU times: user 10.5 s, sys: 2.1 s, total: 12.6 s
# Wall time: 23.5 s

# %% [markdown]
# To run the above distributedly, we will set up a Dask DataFrame with all the URLs of the file names:

# %%
tess_url = f"http://{SERVER_IP}:8000/spatial_signatures/tessellation/"
tess_path = "../../urbangrammar_samba/spatial_signatures/tessellation/"
chunk_names = pandas.DataFrame({
    "file": [f"{tess_url}/{i}" for i in os.listdir(tess_path) if i[-3:]==".pq"]
})
chunk_names = dd.from_pandas(chunk_names, chunksize=1)

# %% [markdown]
# Now we can map the computation of each chunk across the cluster:

# %%
# %%time
ndvis = chunk_names["file"].map_partitions(ndvi_from_chunk, 
                                   meta=(None, 'f8')
                                  ).compute()
# Out:
# distributed.scheduler - INFO - Receive client connection: Client-worker-55b22b09-3296-11eb-8020-a664d571bf36
# distributed.core - INFO - Starting established connection
# distributed.scheduler - INFO - Receive client connection: Client-worker-5698289a-3296-11eb-8020-26e77d64672b
# distributed.core - INFO - Starting established connection
# distributed.scheduler - INFO - Receive client connection: Client-worker-56a81d51-3296-11eb-8020-da52d610c47f
# distributed.core - INFO - Starting established connection
# distributed.scheduler - INFO - Receive client connection: Client-worker-56e002a9-3296-11eb-8021-46bbc0b220bc
# distributed.core - INFO - Starting established connection
# distributed.scheduler - INFO - Receive client connection: Client-worker
memory: 0, processing: 0>
# distributed.scheduler - INFO - Starting worker compute stream, tcp://10.1.151.203:35899
# distributed.core - INFO - Starting established connection
# distributed.scheduler - INFO - Receive client connection: Client-worker-a1efc14c-3296-11eb-8052-da4b82bf9f34
# distributed.core - INFO - Starting established connection
# distributed.scheduler - INFO - Receive client connection: Client-worker-a2621df1-3296-11eb-8054-660300c5058e
# distributed.core - INFO - Starting established connection
# distributed.scheduler - INFO - Receive client connection: Client-worker-a2bfefb4-3296-11eb-8052-12460ee0bc66
# distributed.core - INFO - Starting established connection
# distributed.scheduler - INFO - Remove client Client-worker-777d05df-3296-11eb-8068-d66cedeaf12a
# distributed.scheduler - INFO - Remove worker <Worker 'tcp://10.1.151.198:37199', name: 9, memory: 6, processing: 4>
# distributed.core - INFO - Removing comms to tcp://10.1.151.198:37199
# distributed.scheduler - INFO - Close client connection: Client-worker-777d05df-3296-11eb-8068-d66cedeaf12a
# distributed.scheduler - INFO - Register worker <Worker 'tcp://10.1.151.198:46339', name: 9, memory: 0, processing: 0>
# distributed.scheduler - INFO - Starting worker compute stream, tcp://10.1.151.198:46339
# distributed.core - INFO - Starting established connection
# distributed.scheduler - INFO - Receive client connection: Client-worker-a4e5d353-3296-11eb-80b1-3aa4aae649b1
# distributed.core - INFO - Starting established connection
# distributed.scheduler - INFO - Remove client Client-worker-5cb46abe-3296-11eb-8018-c618d46e670c
# distributed.scheduler - INFO - Close client connection: Client-worker-5cb46abe-3296-11eb-8018-c618d46e670c
# distributed.scheduler - INFO - Remove worker <Worker 'tcp://10.1.232.21:46163', name: 30, memory: 5, processing: 2>
# distributed.core - INFO - Removing comms to tcp://10.1.232.21:46163
# distributed.scheduler - INFO - Register worker <Worker 'tcp://10.1.232.21:37671', name: 30, memory: 0, processing: 0>
# distributed.scheduler - INFO - Starting worker compute stream, tcp://10.1.232.21:37671
# distributed.core - INFO - Starting established connection
# distributed.scheduler - INFO - Remove client Client-worker-7cbbc198-3296-11eb-8069-8a07bd078ccd
# distributed.scheduler - INFO - Remove worker <Worker 'tcp://10.1.151.201:35079', name: 2, memory: 6, processing: 4>
# distributed.core - INFO - Removing comms to tcp://10.1.151.201:35079
# distributed.scheduler - INFO - Close client connection: Client-worker-7cbbc198-3296-11eb-8069-8a07bd078ccd
# distributed.scheduler - INFO - Register worker <Worker 'tcp://10.1.151.201:37461', name: 2, memory: 0, processing: 0>
# distributed.scheduler - INFO - Starting worker compute stream, tcp://10.1.151.201:37461
# distributed.core - INFO - Starting established connection
# distributed.scheduler - INFO - Remove client Client-worker-9e6f54bd-3296-11eb-80af-b29e3257f6c0
# distributed.scheduler - INFO - Remove worker <Worker 'tcp://10.1.151.208:37203', name: 6, memory: 8, processing: 3>
# distributed.core - INFO - Removing comms to tcp://10.1.151.208:37203
# distributed.scheduler - INFO - Close client connection: Client-worker-9e6f54bd-3296-11eb-80af-b29e3257f6c0
# distributed.scheduler - INFO - Remove client Client-worker-87df6a0d-3296-11eb-8068-864182d5fd8e
# distributed.scheduler - INFO - Remove worker <Worker 'tcp://10.1.151.210:36491', name: 36, memory: 6, processing: 5>
# distributed.core - INFO - Removing comms to tcp://10.1.151.210:36491
# distributed.scheduler - INFO - Close client connection: Client-worker-87df6a0d-3296-11eb-8068-864182d5fd8e
# distributed.scheduler - INFO - Register worker <Worker 'tcp://10.1.151.208:42501', name: 6, memory: 0, processing: 0>
# distributed.scheduler - INFO - Starting worker compute stream, tcp://10.1.151.208:42501
# distributed.core - INFO - Starting established connection
# distributed.scheduler - INFO - Register worker <Worker 'tcp://10.1.151.210:38901', name: 36, memory: 0, processing: 0>
# distributed.scheduler - INFO - Starting worker compute stream, tcp://10.1.151.210:38901
# distributed.core - INFO - Starting established connection
# distributed.scheduler - INFO - Remove client Client-worker-9030f79b-3296-11eb-8052-a647dcf1fc15
# distributed.scheduler - INFO - Remove worker <Worker 'tcp://10.1.193.206:43207', name: 3, memory: 6, processing: 4>
# distributed.core - INFO - Removing comms to tcp://10.1.193.206:43207
# distributed.scheduler - INFO - Close client connection: Client-worker-9030f79b-3296-11eb-8052-a647dcf1fc15
# ---------------------------------------------------------------------------
# KilledWorker                              Traceback (most recent call last)
# <timed exec> in <module>
#
# /opt/conda/lib/python3.8/site-packages/dask/base.py in compute(self, **kwargs)
#     165         dask.base.compute
#     166         """
# --> 167         (result,) = compute(self, traverse=False, **kwargs)
#     168         return result
#     169
#
# /opt/conda/lib/python3.8/site-packages/dask/base.py in compute(*args, **kwargs)
#     450         postcomputes.append(x.__dask_postcompute__())
#     451
# --> 452     results = schedule(dsk, keys, **kwargs)
#     453     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     454
#
# /opt/conda/lib/python3.8/site-packages/distributed/client.py in get(self, dsk, keys, restrictions, loose_restrictions, resources, sync, asynchronous, direct, retries, priority, fifo_timeout, actors, **kwargs)
#    2723                     should_rejoin = False
#    2724             try:
# -> 2725                 results = self.gather(packed, asynchronous=asynchronous, direct=direct)
#    2726             finally:
#    2727                 for f in futures.values():
#
# /opt/conda/lib/python3.8/site-packages/distributed/client.py in gather(self, futures, errors, direct, asynchronous)
#    1984             else:
#    1985                 local_worker = None
# -> 1986             return self.sync(
#    1987                 self._gather,
#    1988                 futures,
#
# /opt/conda/lib/python3.8/site-packages/distributed/client.py in sync(self, func, asynchronous, callback_timeout, *args, **kwargs)
#     830             return future
#     831         else:
# --> 832             return sync(
#     833                 self.loop, func, *args, callback_timeout=callback_timeout, **kwargs
#     834             )
#
# /opt/conda/lib/python3.8/site-packages/distributed/utils.py in sync(loop, func, callback_timeout, *args, **kwargs)
#     338     if error[0]:
#     339         typ, exc, tb = error[0]
# --> 340         raise exc.with_traceback(tb)
#     341     else:
#     342         return result[0]
#
# /opt/conda/lib/python3.8/site-packages/distributed/utils.py in f()
#     322             if callback_timeout is not None:
#     323                 future = asyncio.wait_for(future, callback_timeout)
# --> 324             result[0] = yield future
#     325         except Exception as exc:
#     326             error[0] = sys.exc_info()
#
# /opt/conda/lib/python3.8/site-packages/tornado/gen.py in run(self)
#     760
#     761                     try:
# --> 762                         value = future.result()
#     763                     except Exception:
#     764                         exc_info = sys.exc_info()
#
# /opt/conda/lib/python3.8/site-packages/distributed/client.py in _gather(self, futures, errors, direct, local_worker)
#    1849                             exc = CancelledError(key)
#    1850                         else:
# -> 1851                             raise exception.with_traceback(traceback)
#    1852                         raise exc
#    1853                     if errors == "skip":
#
# KilledWorker: ("('ndvi_from_chunk-d563b338d9a3ff805a9851789d5dd4c6', 89)", <Worker 'tcp://10.1.193.206:43207', name: 3, memory: 0, processing: 4>)

# %%
ndvis
# Out:
# hindex
# c011e675448t0000    0.550900
# c011e675448t0052    0.505567
# c011e675448t0053    0.485811
# c011e675448t0054    0.526588
# c011e675448t0037    0.521815
# c046e432985t0000    0.448482
# c046e432985t0059    0.198398
# c046e432985t0040    0.335527
# c046e432985t0041    0.623561
# c046e432985t0038    0.613240
# c040e541154t0000    0.224681
# c040e541154t0001    0.229765
# c040e160280t0002    0.463784
# c040e160280t0015    0.631372
# c040e160280t0012    0.293753
# c073e716445t0053    0.351165
# c073e716445t0010    0.412447
# c073e716445t0011    0.405551
# c073e716445t0012    0.521756
# c073e716445t0013    0.358216
# dtype: float64

# %% [markdown]
# ---
#
# ## [DEPRECATED] Alternative using `geocube`

# %% [markdown]
# The alternative involves [`geocube`'s zonal stats](https://corteva.github.io/geocube/stable/examples/zonal_statistics.html) and `make_geocube`. In this approach, we first rasterize our ET cells in a grid aligned with the mosaic, then calculate the NDVI. At present, this approach is discarded because the resolution of the mosaic (10m) makes it too coarse to obtain an NDVI for each cell.

# %%
from geocube.api.core import make_geocube

# %% [markdown]
# We use the same set of ET cells:

# %%
url = f"http://{SERVER_IP}:8000/spatial_signatures/tessellation/tess_6.pq"
tst = geopandas.read_parquet(url)

# %%
tst_sub = tst.cx[315891.95:330000, 213727.69:250000]
tst_sub.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# Int64Index: 2049 entries, 15006 to 258237
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   uID          2049 non-null   int64
#  1   geometry     2049 non-null   geometry
#  2   enclosureID  2049 non-null   int64
# dtypes: geometry(1), int64(2)
# memory usage: 64.0 KB

# %% [markdown]
# Before rasterization, we need to load the segment of the mosaic that overlaps (note no bits are streamed to memory, all lazy evaluation):

# %%
ndvi_segment = ndvi.rio.clip_box(*tst_sub.total_bounds)

# %% [markdown]
# We need to rasterize the features:

# %%
# %%time
out_grid = make_geocube(
    vector_data = tst_sub,
    measurements=["uID"],
    like=ndvi_segment
)
# Out:
# CPU times: user 318 ms, sys: 5.81 ms, total: 324 ms
# Wall time: 323 ms

# %% [markdown]
# This creates a `DataSet` object with a rasterised version of the tesselations in `tst`. Now we append the NDVI:

# %%
out_grid["ndvi"] = ndvi_segment

# %% [markdown]
# And with both aligned, we can group by each `uID` and calculate average NDVI:

# %%
# %%time
g = out_grid.drop("spatial_ref")\
            .groupby(out_grid["uID"])
# Out:
# CPU times: user 598 ms, sys: 2.23 ms, total: 601 ms
# Wall time: 598 ms

# %% [markdown]
# And we can get the average easily:

# %%
# %%time
ndvi_mean = g.mean()
# Out:
# CPU times: user 6.21 s, sys: 2.89 ms, total: 6.22 s
# Wall time: 6.21 s

# %%
mn = ndvi_mean.to_dataframe()[["ndvi"]]
# Out:
# /opt/conda/lib/python3.8/site-packages/dask/core.py:121: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# /opt/conda/lib/python3.8/site-packages/dask/array/numpy_compat.py:41: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %%
geom2ndvi(tst_sub.query("uID == 6712717").iloc[0], ndvi)
# Out:
# /opt/conda/lib/python3.8/site-packages/dask/core.py:121: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# 0.6968843539763994

# %%
# %time out = tst_sub.head().apply(lambda r: geom2ndvi(r, ndvi), axis=1)
# Out:
# /opt/conda/lib/python3.8/site-packages/dask/core.py:121: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# /opt/conda/lib/python3.8/site-packages/dask/core.py:121: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# /opt/conda/lib/python3.8/site-packages/dask/core.py:121: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# /opt/conda/lib/python3.8/site-packages/dask/core.py:121: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))
# CPU times: user 1.6 s, sys: 14.6 ms, total: 1.62 s
# Wall time: 1.6 s
# /opt/conda/lib/python3.8/site-packages/dask/core.py:121: RuntimeWarning: invalid value encountered in true_divide
#   return func(*(_execute_task(a, cache) for a in args))

# %%
tst_sub.query("uID == 6712717")
# Out:
#            uID                                           geometry  enclosureID
# 22988  6712717  POLYGON Z ((329700.369 234529.467 0.000, 32945...       658102

# %%
mn.head()
# Out:
#                ndvi
# uID
# 6712717.0       NaN
# 6712718.0  0.682241
# 6712719.0  0.675091
# 6712720.0       NaN
# 6712721.0  0.537544
